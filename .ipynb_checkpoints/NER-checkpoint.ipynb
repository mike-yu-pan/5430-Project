# %% [markdown]
# # Named Entity Recognition

# %% [markdown]
# ## Step 1. Reading JSON string file into a Python array of dictionaries

# %%
import json

# %%
with open("nyt_articles2.json", 'r') as f:
    newsfeeds = json.load(f)

len(newsfeeds)
# Out:
# 1158

# %%
import pandas as pd
df = pd.DataFrame(newsfeeds)

# %% [markdown]
# ## Step 2. Refinitiv Open Calais
# Reference: https://developers.refinitiv.com/en/article-catalog/article/intelligent-tagging-extract-information-api-response

# %% [markdown]
# ### 2.1 Fetch all article URLs, headlines, and abstract

# %%
import requests

# %%
df.keys()
# Out:
# Index(['Headline', 'Abstract', 'Lead_Paragraph', 'Snippet', 'Published_date',
#        'Author', 'News_desk', 'URL', 'Source'],
#       dtype='object')

# %%
all_URL = []
for index, row in df.iterrows():
    all_URL.append(row["URL"])

# %%
all_headlines = []
for index, row in df.iterrows():
    all_headlines.append(row["Headline"])

# %%
all_snippets = []
for index, row in df.iterrows():
    all_snippets.append(row["Snippet"])

# %%
# print(len(all_URL))
# print(len(all_headlines))
# print(len(all_snippets))

# %% [markdown]
# ### 2.2 NER tagging for all articles

# %% [markdown]
# Replace with your own token!

# %%
all_JsonResponses = [] 

for url in all_URL:
    url = url
    headers = {}
    HTMLResponse = requests.request('GET', url, headers=headers)
    contentText = HTMLResponse.text
    headType = 'text/html'
    
    token = your_own_token
    url = 'https://api-eit.refinitiv.com/permid/calais'
    payload = contentText.encode('utf8')
    headers = {
        'Content-Type': headType,
        'x-ag-access-token': token,
        #'x-calais-selectiveTags': 'Company,CompanyLocation, Movie, Organization, Person',
        'outputformat': 'application/json'
        }

    TRITResponse = requests.request('POST', url, data=payload, headers=headers)
    TRITTextResponse = TRITResponse.text
    
    TRITJsonResponse = json.loads(TRITTextResponse)

    all_JsonResponses.append(TRITJsonResponse)
        
with open("NER_Tagging.json", "w") as json_file:
    json.dump(all_JsonResponses, json_file, indent=4)

# %%
all_headlines[2]
# Out:
# 'The 25 Best Films of the 21st Century So Far.'

# %%
all_JsonResponses[2]
# Out:
# {'doc': {'info': {'id': 'http://id.opencalais.com/ENK1a2wRBU8VNS0-hgI2*A',
#    'ontology': 'http://trit-us-east-1-sharedamd.int.refinitiv.com/owlschema/0.5.2/onecalais.owl.allmetadata.xml',
#    'docId': 'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1',
#    'document': "<body> The 25 Best Films of the 21st Century So Far.\nJUNE 9, 2017\nA.O. Scott and Manohla Dargis rank the best films made since 2000.\nThe 25 Best Films of the 21st Century\nSo Far.\n查看简体中文版 (Read in Chinese) Leer en español (Read in Spanish)\nWe are now approximately one-sixth of the way through the 21st century, and thousands of movies have already been released. Which means that it’s high time for the sorting – and the fighting – to start. As the chief film critics of The Times, we decided to rank, with some help from cinema savants on Facebook, the top 25 movies that are destined to be the classics of the future. While we’re sure almost everyone will agree with our choices, we’re equally sure that those of you who don’t will let us know.\nBy Manohla Dargis  and A.O. Scott\nWith contributions from Kathryn Bigelow, Guillermo del Toro, Ava DuVernay, Barry Jenkins, Richard Linklater, Robert Pattinson and Michelle Williams\nJune 9, 2017\nThere Will Be Blood\nDirected by Paul Thomas Anderson, 2007\n“ There Will Be Blood ” tells the story of an American oilman, Daniel Plainview, who persuades the locals in a California ranching town to let him drill on their land. He also establishes an uneasy rivalry with a preacher, Eli Sunday, and the two men, each selling his own brand of faith, enact the timeless battle between God and Mammon – though who is on what side is not always clear.\nManohla Dargis Paul Thomas Anderson’s “There Will Be Blood” is a 21st-century masterpiece about love, death, faith, greed and all the oil and blood gushing through the American 20th century. It distills a harrowing story through a prospector – played with demonic intensity by Daniel Day-Lewis – who pursues a savage, hollow dream. He embodies the best of the United States only to become the very worst of it.\nThe film offers a profound and deeply unsettling vision of the country, but it’s also a testament to one of this nation’s sublime achievements: the movies. The story creeps alive in 1898 with Plainview digging in a hole like a primordial creature, a sequence that invokes the dawn-of-man opener in “2001: A Space Odyssey.” A brilliant two and a half hours later, “There Will Be Blood” closes around 1927 by making good on its ominous title (it’s a gusher!) and nodding at “Citizen Kane,” a masterwork that ushered in a new American cinematic age.\nA.O. Scott While I am endlessly fascinated by what this movie is about – the dynamic, infernal spirit of American capitalism; the dialectic of faith and greed; the invention of California; the melodrama of modern masculinity – I am perpetually astonished by what it is. It is stranger than any of its themes, mightier than its influence and bigger than any of the genres it explores.\nThat opening sequence lasts almost 15 minutes before the first line of dialogue is uttered, and it sets the table (or stirs the milkshake) for the many bravura set pieces that follow, like the explosion of the drilling rig midway through. The grandeur of Mr. Anderson’s vision is matched by the precision of his technique. At no moment do you doubt that anything happened exactly how he is showing it, even as he takes abundant liberty with the historical record and his literary source (Upton Sinclair’s novel “Oil!”). But you are also aware of his artistic self-confidence, and the way he has marshaled the talents of his cast and collaborators (notably the cinematographer Robert Elswit and the composer Jonny Greenwood) in the service of his ideas.\nI never tire of thinking about “There Will Be Blood.” But every time I watch it, I find it outruns all my thoughts. Not many films do that.\nDargis It’s still fascinating to see how Mr. Anderson drew from two traditions to make the film: classical Hollywood cinema and European art film. “There Will Be Blood” is as pleasurable – and rewatchable – as an old-studio masterwork like “The Big Sleep” and his impeccable craft is of course one reason. Yet much as Martin Scorsese and Fran ...
#    'docTitle': '',
#    'docDate': '2023-08-06 07:19:34.308'},
#   'meta': {'contentType': 'text/html',
#    'processingVer': 'AllMetadata',
#    'serverVersion': 'N/A',
#    'stagsVer': 'defaultVersion',
#    'submissionDate': '2023-08-06 07:19:29.105',
#    'submitterCode': '0ca6a864-5659-789d-5f32-f365f695e757',
#    'signature': 'digestalg-1|cNxeRj08LrH3wyijB2dSfFRb4Qg=|Xwnr/HeDhKV3CRN0QxgyvscEVDeGLWgsjE7V39k8xQy8L0x+f5UStQ==',
#    'language': 'English'}},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/cat/1': {'_typeGroup': 'topics',
#   'forenduserdisplay': 'false',
#   'score': 0.993,
#   'name': 'Entertainment_Culture'},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/lid/DefaultLangId': {'_typeGroup': 'language',
#   'language': 'http://d.opencalais.com/lid/DefaultLangId/English',
#   'forenduserdisplay': 'false',
#   'permid': '505062'},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/SocialTag/1': {'_typeGroup': 'socialTag',
#   'id': 'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/SocialTag/1',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/b0dfef92-99d9-3dd1-9061-faa7584902da',
#   'forenduserdisplay': 'true',
#   'name': '201',
#   'importance': '1',
#   'originalValue': '201 (South Park)'},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/SocialTag/2': {'_typeGroup': 'socialTag',
#   'id': 'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/SocialTag/2',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/e40d83d7-b745-33e7-8a8d-983bd97f538f',
#   'forenduserdisplay': 'true',
#   'name': 'Jyllands-Posten Muhammad cartoons controversy',
#   'importance': '1',
#   'originalValue': 'Jyllands-Posten Muhammad cartoons controversy'},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/SocialTag/3': {'_typeGroup': 'socialTag',
#   'id': 'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/SocialTag/3',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/66a925d7-4384-3a79-9b09-2222ac6e1de7',
#   'forenduserdisplay': 'true',
#   'name': 'Self-censorship',
#   'importance': '1',
#   'originalValue': 'Self-censorship'},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/SocialTag/4': {'_typeGroup': 'socialTag',
#   'id': 'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/SocialTag/4',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/0810fa5e-9378-369d-b412-e6ad2d56a402',
#   'forenduserdisplay': 'true',
#   'name': 'So Far',
#   'importance': '2',
#   'originalValue': 'So Far'},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/SocialTag/5': {'_typeGroup': 'socialTag',
#   'id': 'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/SocialTag/5',
#   'socialTag': 'http://d.opencalais.com/genericHasher-1/e938a2b8-33f2-308d-852d-1da4fe588ac8',
#   'forenduserdisplay': 'true',
#   'name': 'VFA-201',
#   'importance': '2',
#   'originalValue': 'VFA-201'},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/Industry/1': {'_typeGroup': 'industry',
#   'forenduserdisplay': 'false',
#   'name': 'Apparel & Accessories Retailers (NEC)',
#   'rcscode': 'B:1511',
#   'permid': '4294951490',
#   'relevance': 0.2},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/Industry/2': {'_typeGroup': 'industry',
#   'forenduserdisplay': 'false',
#   'name': 'Broadcasting (NEC)',
#   'rcscode': 'B:1446',
#   'permid': '4294951555',
#   'relevance': 0.2},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/Industry/3': {'_typeGroup': 'industry',
#   'forenduserdisplay': 'false',
#   'name': 'Entertainment Production (NEC)',
#   'rcscode': 'B:1450',
#   'permid': '4294951551',
#   'relevance': 0.2},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/Industry/4': {'_typeGroup': 'industry',
#   'forenduserdisplay': 'false',
#   'name': 'Automobiles & Multi Utility Vehicles',
#   'rcscode': 'B:1294',
#   'permid': '4294951707',
#   'relevance': 0},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/Industry/5': {'_typeGroup': 'industry',
#   'forenduserdisplay': 'false',
#   'name': 'Social Media & Networking',
#   'rcscode': 'B:1806',
#   'permid': '4294951195',
#   'relevance': 0},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/Industry/6': {'_typeGroup': 'industry',
#   'forenduserdisplay': 'false',
#   'name': 'Public Finance Activities',
#   'rcscode': 'B:1889',
#   'permid': '1004365555',
#   'relevance': 0.2},
#  'http://d.opencalais.com/dochash-1/7b933617-6135-3bf1-a1c5-9713078245f1/ComponentVersions': {'_typeGroup': 'versions',
#   'version': ['Deals Index:202308060700:202308060700',
#    'config-blackList-DIY:239555313:239555313',
#    'index-refineries:202107102126:202107102126',
#    'config-physicalAssets-powerStations:1227:1227',
#    'NextTags:2.5.191-legacy-trit-release-master:191',
#    'config-sca-DataPackage:50:50',
#    'config-companyNe:90548:90548',
#    'People Index:202308060605:202308060605',
#    'config-negativeSignature:994:994',
#    'Dial4J:2.0.17:17',
#    'OA Override:90547:90547',
#    'People Override:994:994',
#    'index-sluglines:202010230725:202010230725',
#    'index-company-oa3:202209072147:202209072147',
#    'index-vessels:202206111824:202206111824',
#    'config-forEndUserDisplay:4:4',
#    'config-refineries:994:994',
#    'config-cse-DIY:239562354:239562354',
#    'config-cse:994:994',
#    'config-vessels:994:994',
#    'override-company-DIY:239562354:239562354',
#    'config-physicalAssets-mines:1227:1227',
#    'BlackList:994:994',
#    'index-ports:202307291658:202307291658',
#    'config-physicalAssets-ports:994:994',
#    'config-drugs:994:994']},
#  'http://d.opencalais.com/pershash-1/baae0d71-4bf9-3ea7-8c4b-7fc24295bb16': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'confidencelevel': '0.98',
#   'name': 'Yi Yi',
#   'nationality': 'N/A',
#   'persontype': 'N/A',
#   'commonname': 'Yi Yi',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[States and also, tragically, the last film ]he[ completed before his death in 2007 . It’s an]',
#     'prefix': 'States and also, tragically, the last film ',
#     'exact': 'he',
#     'suffix': ' completed before his death in 2007 . It’s an',
#     'offset': 17940,
#     'length': 2},
#    {'detection': '[Romanian movie? Oh, man. You’ve gotta see it.”\n]Yi Yi[\nDirected by Edward Yang, 2000\nA.O. Scott]',
#     'prefix': 'Romanian movie? Oh, man. You’ve gotta see it.”\n',
#     'exact': 'Yi Yi',
#     'suffix': '\nDirected by Edward Yang, 2000\nA.O. Scott',
#     'offset': 16447,
#     'length': 5},
#    {'detection': '[and a two.” It keeps on going to infinity.\n“Yi ]Yi[” is one of those movies you remember less as]',
#     'prefix': 'and a two.” It keeps on going to infinity.\n“Yi ',
#     'exact': 'Yi',
#     'suffix': '” is one of those movies you remember less as',
#     'offset': 18710,
#     'length': 2},
#    {'detection': '[– in the New Taiwan cinema of the 1990s. “]Yi Yi[” was his first film to be released in the United]',
#     'prefix': '– in the New Taiwan cinema of the 1990s. “',
#     'exact': 'Yi Yi',
#     'suffix': '” was his first film to be released in the United',
#     'offset': 17842,
#     'length': 5},
#    {'detection': '[tragically, the last film he completed before ]his[ death in 2007 . It’s an excellent introduction]',
#     'prefix': 'tragically, the last film he completed before ',
#     'exact': 'his',
#     'suffix': ' death in 2007 . It’s an excellent introduction',
#     'offset': 17960,
#     'length': 3},
#    {'detection': '[one of the main family’s Taipei neighbors.\n“Yi ]Yi[” is available from the Criterion Collection and]',
#     'prefix': 'one of the main family’s Taipei neighbors.\n“Yi ',
#     'exact': 'Yi',
#     'suffix': '” is available from the Criterion Collection and',
#     'offset': 18873,
#     'length': 2},
#    {'detection': '[the New Taiwan cinema of the 1990s. “Yi Yi” was ]his[ first film to be released in the United States]',
#     'prefix': 'the New Taiwan cinema of the 1990s. “Yi Yi” was ',
#     'exact': 'his',
#     'suffix': ' first film to be released in the United States',
#     'offset': 17853,
#     'length': 3}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.984',
#    'dblookup': '0.95',
#    'resolution': '0.0',
#    'aggregate': '0.98'}},
#  'http://d.opencalais.com/pershash-1/ce99dda6-89f7-3455-8739-40a6d0d4bdbf': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'nationality': 'N/A',
#   'lastname': 'Nelson',
#   'confidencelevel': '0.976',
#   'name': 'Nelson',
#   'persontype': 'N/A',
#   'commonname': 'Nelson',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[A ghost story? A musical? A rugby movie about ]Nelson[ Mandela? Why not?\nBut Mr. Eastwood has always]',
#     'prefix': 'A ghost story? A musical? A rugby movie about ',
#     'exact': 'Nelson',
#     'suffix': ' Mandela? Why not?\nBut Mr. Eastwood has always',
#     'offset': 9665,
#     'length': 6}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.953',
#    'dblookup': '0.97',
#    'resolution': '0.0',
#    'aggregate': '0.976'}},
#  'http://d.opencalais.com/pershash-1/c6ad6139-5163-36cb-bdc5-891d34fc37ca': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'confidencelevel': '0.95',
#   'name': 'Margarete Weathers',
#   'firstname': 'Margarete',
#   'nationality': 'N/A',
#   'persontype': 'N/A',
#   'lastname': 'Weathers',
#   'commonname': 'Margarete Weathers',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[Rats have no business in the kitchen, right? ]Margarete Weathers[ on Facebook\nToy Story 3 - felt destroyed by the]',
#     'prefix': 'Rats have no business in the kitchen, right? ',
#     'exact': 'Margarete Weathers',
#     'suffix': ' on Facebook\nToy Story 3 - felt destroyed by the',
#     'offset': 22461,
#     'length': 18}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.97',
#    'dblookup': '0.0',
#    'resolution': '0.0',
#    'aggregate': '0.95'}},
#  'http://d.opencalais.com/pershash-1/9b32cf5d-0540-3de7-a31e-af37865ef892': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'name': 'Carl',
#   'nationality': 'N/A',
#   'confidencelevel': '0.98',
#   'lastname': 'Carl',
#   'persontype': 'N/A',
#   'commonname': 'Carl',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[least a half-dozen films: the wordless story of ]Carl[ and Ellie’s marriage in “Up”; the first meeting]',
#     'prefix': 'least a half-dozen films: the wordless story of ',
#     'exact': 'Carl',
#     'suffix': ' and Ellie’s marriage in “Up”; the first meeting',
#     'offset': 19879,
#     'length': 4}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.953',
#    'dblookup': '0.97',
#    'resolution': '0.0',
#    'aggregate': '0.98'}},
#  'http://d.opencalais.com/pershash-1/390a932b-704b-31bf-b3be-4ac695673217': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'persontype': 'N/A',
#   'middlename': 'Beaser',
#   'name': 'Barb Beaser-Konschak',
#   'lastname': 'Konschak',
#   'nationality': 'N/A',
#   'firstname': 'Barb',
#   'confidencelevel': '0.95',
#   'commonname': 'Barb Beaser-Konschak',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': "[ (still want, actually) to have Sully in my life. ]Barb Beaser-Konschak[ on Facebook\nRatatouille, just because it's so]",
#     'prefix': ' (still want, actually) to have Sully in my life. ',
#     'exact': 'Barb Beaser-Konschak',
#     'suffix': " on Facebook\nRatatouille, just because it's so",
#     'offset': 22322,
#     'length': 20}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.97',
#    'dblookup': '0.0',
#    'resolution': '0.0',
#    'aggregate': '0.95'}},
#  'http://d.opencalais.com/genericHasher-1/3405ace1-b6ba-3801-a25d-4079cd1335b1': {'_typeGroup': 'entities',
#   '_type': 'Position',
#   'forenduserdisplay': 'false',
#   'name': 'composer',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Position',
#   'instances': [{'detection': '[(notably the cinematographer Robert Elswit and ]the composer[ Jonny Greenwood) in the service of his ideas.\nI]',
#     'prefix': '(notably the cinematographer Robert Elswit and ',
#     'exact': 'the composer',
#     'suffix': ' Jonny Greenwood) in the service of his ideas.\nI',
#     'offset': 3425,
#     'length': 12}],
#   'relevance': 0.2},
#  'http://d.opencalais.com/pershash-1/13f30c45-932a-3dff-8cbd-2514252f77d7': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'firstname': 'Dina',
#   'middlename': 'Dasom',
#   'nationality': 'N/A',
#   'lastname': 'Anya',
#   'confidencelevel': '0.963',
#   'name': 'Dina Dasom Anya',
#   'persontype': 'N/A',
#   'commonname': 'Dina Dasom Anya',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': "[movie would you choose?\nAll !! Can't choose. ]Dina Dasom Anya[ on Facebook\nMy Top 3 would have to be 1.]",
#     'prefix': "movie would you choose?\nAll !! Can't choose. ",
#     'exact': 'Dina Dasom Anya',
#     'suffix': ' on Facebook\nMy Top 3 would have to be 1.',
#     'offset': 21072,
#     'length': 15}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.978',
#    'dblookup': '0.0',
#    'resolution': '0.0',
#    'aggregate': '0.963'}},
#  'http://d.opencalais.com/comphash-1/fc16244a-56d5-3140-b66d-435496c47fcf': {'_typeGroup': 'entities',
#   '_type': 'Company',
#   'forenduserdisplay': 'true',
#   'name': 'Monsters Inc.',
#   'nationality': 'N/A',
#   'confidencelevel': '1.0',
#   'recognizedas': 'name',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'instances': [{'detection': '[what about “Finding Nemo”? “The Incredibles”? “]Monsters, Inc.[”? How could we pick just one?\nIn fairness to all]',
#     'prefix': 'what about “Finding Nemo”? “The Incredibles”? “',
#     'exact': 'Monsters, Inc.',
#     'suffix': '”? How could we pick just one?\nIn fairness to all',
#     'offset': 20123,
#     'length': 14},
#    {'detection': '[Anya on Facebook\nMy Top 3 would have to be 1. ]Monsters Inc.[, 2. Wall-E, 3. Inside Out. The honorary mention]',
#     'prefix': 'Anya on Facebook\nMy Top 3 would have to be 1. ',
#     'exact': 'Monsters Inc.',
#     'suffix': ', 2. Wall-E, 3. Inside Out. The honorary mention',
#     'offset': 21129,
#     'length': 13},
#    {'detection': '[language. Rachel Morgan Spencer on Facebook\n]Monsters, Inc.[ The message of laughter over fear really stuck]',
#     'prefix': 'language. Rachel Morgan Spencer on Facebook\n',
#     'exact': 'Monsters, Inc.',
#     'suffix': ' The message of laughter over fear really stuck',
#     'offset': 22187,
#     'length': 14}],
#   'relevance': 0.5,
#   'resolutions': [{'name': 'Monsters, Inc.',
#     'permid': '5078514169',
#     'ispublic': 'false',
#     'commonname': 'Monsters, In',
#     'score': 0.006171134,
#     'id': 'https://permid.org/1-5078514169'}],
#   'confidence': {'statisticalfeature': '0.872',
#    'dblookup': '0.0',
#    'resolution': '0.006171134',
#    'aggregate': '1.0'}},
#  'http://d.opencalais.com/pershash-1/e4c05a1f-c7ff-3282-bc11-261e76e3243d': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'confidencelevel': '0.95',
#   'name': 'Leia Becker',
#   'nationality': 'N/A',
#   'lastname': 'Becker',
#   'firstname': 'Leia',
#   'persontype': 'N/A',
#   'commonname': 'Leia Becker',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[ scene, because, you know, ninjas cutting onions. ]Leia Becker[ on Facebook\nMost people can only see the]',
#     'prefix': ' scene, because, you know, ninjas cutting onions. ',
#     'exact': 'Leia Becker',
#     'suffix': ' on Facebook\nMost people can only see the',
#     'offset': 21261,
#     'length': 11}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.97',
#    'dblookup': '0.0',
#    'resolution': '0.0',
#    'aggregate': '0.95'}},
#  'http://d.opencalais.com/genericHasher-1/36daa760-d1f8-30fe-8879-608d6e85d260': {'_typeGroup': 'entities',
#   '_type': 'Country',
#   'forenduserdisplay': 'true',
#   'name': 'Venezuela',
#   'resolutions': [{'name': 'Venezuela',
#     'shortname': 'Venezuela',
#     'latitude': '9.39275359477',
#     'longitude': '-66.3562091503',
#     'rcscode': 'G:2K',
#     'permid': '100325'}],
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Country',
#   'instances': [{'detection': '[ only see the terrible crisis currently affecting ]Venezuela[. I was a kid when I first saw Up in Venezuela.]',
#     'prefix': ' only see the terrible crisis currently affecting ',
#     'exact': 'Venezuela',
#     'suffix': '. I was a kid when I first saw Up in Venezuela.',
#     'offset': 21350,
#     'length': 9},
#    {'detection': '[Venezuela. I was a kid when I first saw Up in ]Venezuela[. Someone could actually see so much beauty]',
#     'prefix': 'Venezuela. I was a kid when I first saw Up in ',
#     'exact': 'Venezuela',
#     'suffix': '. Someone could actually see so much beauty',
#     'offset': 21396,
#     'length': 9}],
#   'relevance': 0.2},
#  'http://d.opencalais.com/genericHasher-1/fdf880e4-105d-30b0-8a8b-9e1cee28f53b': {'_typeGroup': 'entities',
#   '_type': 'Journalist',
#   'forenduserdisplay': 'true',
#   'name': 'Manohla Dargis',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Journalist',
#   'instances': [{'detection': '[ that those of you who don’t will let us know.\nBy ]Manohla Dargis[  and A.O. Scott\nWith contributions from Kathryn]',
#     'prefix': ' that those of you who don’t will let us know.\nBy ',
#     'exact': 'Manohla Dargis',
#     'suffix': '  and A.O. Scott\nWith contributions from Kathryn',
#     'offset': 750,
#     'length': 14}],
#   'relevance': 0},
#  'http://d.opencalais.com/pershash-1/f87e03e6-9895-33da-83d2-fd88f31b5308': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'nationality': 'N/A',
#   'name': 'Ava DuVernay',
#   'confidencelevel': '0.98',
#   'firstname': 'Ava',
#   'lastname': 'Duvernay',
#   'persontype': 'N/A',
#   'commonname': 'Ava DuVernay',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[from Kathryn Bigelow, Guillermo del Toro, ]Ava DuVernay[, Barry Jenkins, Richard Linklater, Robert]',
#     'prefix': 'from Kathryn Bigelow, Guillermo del Toro, ',
#     'exact': 'Ava DuVernay',
#     'suffix': ', Barry Jenkins, Richard Linklater, Robert',
#     'offset': 842,
#     'length': 12}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.97',
#    'dblookup': '0.95',
#    'resolution': '0.0',
#    'aggregate': '0.98'}},
#  'http://d.opencalais.com/pershash-1/09e1b905-f7a2-30a8-b191-5ab6702dba65': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'firstname': 'Frankie',
#   'nationality': 'N/A',
#   'confidencelevel': '0.947',
#   'name': 'Frankie Dunn',
#   'lastname': 'Dunn',
#   'persontype': 'N/A',
#   'commonname': 'Frankie Dunn',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[the confidant and conscience of Mr. Eastwood’s ]Frankie Dunn[. Frankie is a trainer haunted by ghosts and]',
#     'prefix': 'the confidant and conscience of Mr. Eastwood’s ',
#     'exact': 'Frankie Dunn',
#     'suffix': '. Frankie is a trainer haunted by ghosts and',
#     'offset': 10343,
#     'length': 12},
#    {'detection': '[and conscience of Mr. Eastwood’s Frankie Dunn. ]Frankie[ is a trainer haunted by ghosts and regrets who]',
#     'prefix': 'and conscience of Mr. Eastwood’s Frankie Dunn. ',
#     'exact': 'Frankie',
#     'suffix': ' is a trainer haunted by ghosts and regrets who',
#     'offset': 10357,
#     'length': 7}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.97',
#    'dblookup': '0.0',
#    'resolution': '0.0',
#    'aggregate': '0.947'}},
#  'http://d.opencalais.com/genericHasher-1/c1681d3f-2378-3e6c-a8bf-0926490cf7fc': {'_typeGroup': 'entities',
#   '_type': 'EntertainmentAwardEvent',
#   'forenduserdisplay': 'false',
#   'name': 'the Cannes Film Festival',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/EntertainmentAwardEvent',
#   'instances': [{'detection': '[gripping, weirdly funny second feature. At ]the Cannes Film Festival[, “ The Death of Mr. Lazarescu ” was a]',
#     'prefix': 'gripping, weirdly funny second feature. At ',
#     'exact': 'the Cannes Film Festival',
#     'suffix': ', “ The Death of Mr. Lazarescu ” was a',
#     'offset': 14613,
#     'length': 24}],
#   'relevance': 0.2},
#  'http://d.opencalais.com/pershash-1/79b2b8ea-7c3b-32ec-9c99-7e8f3838f145': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'lastname': 'Jenkins',
#   'persontype': 'N/A',
#   'confidencelevel': '0.988',
#   'nationality': 'N/A',
#   'firstname': 'Barry',
#   'name': 'Barry Jenkins',
#   'commonname': 'Barry Jenkins',
#   'confidence': {'statisticalfeature': '0.97',
#    'dblookup': '0.95',
#    'resolution': '0.0',
#    'aggregate': '0.988'},
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[Bigelow, Guillermo del Toro, Ava DuVernay, ]Barry Jenkins[, Richard Linklater, Robert Pattinson and]',
#     'prefix': 'Bigelow, Guillermo del Toro, Ava DuVernay, ',
#     'exact': 'Barry Jenkins',
#     'suffix': ', Richard Linklater, Robert Pattinson and',
#     'offset': 856,
#     'length': 13}],
#   'relevance': 0.2},
#  'http://d.opencalais.com/genericHasher-1/47502e9e-923d-3861-b258-fbb94a5fee3e': {'_typeGroup': 'entities',
#   '_type': 'PublishedMedium',
#   'forenduserdisplay': 'false',
#   'name': 'The Times',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/PublishedMedium',
#   'instances': [{'detection': '[– to start. As the chief film critics of ]The Times[, we decided to rank, with some help from cinema]',
#     'prefix': '– to start. As the chief film critics of ',
#     'exact': 'The Times',
#     'suffix': ', we decided to rank, with some help from cinema',
#     'offset': 471,
#     'length': 9}],
#   'relevance': 0.2},
#  'http://d.opencalais.com/pershash-1/5e3664c0-dd63-3ccf-87af-227cdeeee737': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'firstname': 'Daniel',
#   'confidencelevel': '0.973',
#   'lastname': 'Plainview',
#   'name': 'Daniel Plainview',
#   'persontype': 'N/A',
#   'nationality': 'N/A',
#   'commonname': 'Daniel Plainview',
#   'confidence': {'statisticalfeature': '0.983',
#    'dblookup': '0.0',
#    'resolution': '0.0',
#    'aggregate': '0.973'},
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[Blood ” tells the story of an American oilman, ]Daniel Plainview[, who persuades the locals in a California]',
#     'prefix': 'Blood ” tells the story of an American oilman, ',
#     'exact': 'Daniel Plainview',
#     'suffix': ', who persuades the locals in a California',
#     'offset': 1064,
#     'length': 16},
#    {'detection': '[the locals in a California ranching town to let ]him[ drill on their land. He also establishes an]',
#     'prefix': 'the locals in a California ranching town to let ',
#     'exact': 'him',
#     'suffix': ' drill on their land. He also establishes an',
#     'offset': 1144,
#     'length': 3},
#    {'detection': '[ranching town to let him drill on their land. ]He[ also establishes an uneasy rivalry with a]',
#     'prefix': 'ranching town to let him drill on their land. ',
#     'exact': 'He',
#     'suffix': ' also establishes an uneasy rivalry with a',
#     'offset': 1169,
#     'length': 2},
#    {'detection': '[Eli Sunday, and the two men, each selling ]his[ own brand of faith, enact the timeless battle]',
#     'prefix': 'Eli Sunday, and the two men, each selling ',
#     'exact': 'his',
#     'suffix': ' own brand of faith, enact the timeless battle',
#     'offset': 1266,
#     'length': 3}],
#   'relevance': 0.2},
#  'http://d.opencalais.com/pershash-1/b1aee52c-1c34-38fb-b3b1-81fec4f5865c': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'lastname': 'Hambor',
#   'nationality': 'N/A',
#   'persontype': 'N/A',
#   'confidencelevel': '0.95',
#   'name': 'Kyle Hambor',
#   'firstname': 'Kyle',
#   'commonname': 'Kyle Hambor',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[3” and “Inside Out”. Can I be allowed a tie? ]Kyle Hambor[ on Facebook\nWatching Inside Out with my]',
#     'prefix': '3” and “Inside Out”. Can I be allowed a tie? ',
#     'exact': 'Kyle Hambor',
#     'suffix': ' on Facebook\nWatching Inside Out with my',
#     'offset': 22651,
#     'length': 11}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.97',
#    'dblookup': '0.0',
#    'resolution': '0.0',
#    'aggregate': '0.95'}},
#  'http://d.opencalais.com/genericHasher-1/9b732f65-0eb5-3bcc-af49-b23579915138': {'_typeGroup': 'entities',
#   '_type': 'City',
#   'forenduserdisplay': 'true',
#   'name': 'Taipei',
#   'resolutions': [{'name': 'Taipei,Taiwan',
#     'shortname': 'Taipei',
#     'latitude': '25.0333333333',
#     'longitude': '121.533333333',
#     'containedbycountry': 'Taiwan',
#     'rcscode': 'G:14U'}],
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/City',
#   'instances': [{'detection': '[experienced, as if you were one of the Jians’ ]Taipei[ neighbors.\nMr. Yang, who worked in the tech]',
#     'prefix': 'experienced, as if you were one of the Jians’ ',
#     'exact': 'Taipei',
#     'suffix': ' neighbors.\nMr. Yang, who worked in the tech',
#     'offset': 17602,
#     'length': 6},
#    {'detection': '[through the high-rises and busy streets of ]Taipei[, interrupted by a trip to Tokyo. To invoke the]',
#     'prefix': 'through the high-rises and busy streets of ',
#     'exact': 'Taipei',
#     'suffix': ', interrupted by a trip to Tokyo. To invoke the',
#     'offset': 18172,
#     'length': 6},
#    {'detection': '[as if you were one of the main family’s ]Taipei[ neighbors.\n“Yi Yi” is available from the]',
#     'prefix': 'as if you were one of the main family’s ',
#     'exact': 'Taipei',
#     'suffix': ' neighbors.\n“Yi Yi” is available from the',
#     'offset': 18851,
#     'length': 6}],
#   'relevance': 0.2},
#  'http://d.opencalais.com/genericHasher-1/c0bc3dcd-2a0d-3f13-a737-ea4203190351': {'_typeGroup': 'entities',
#   '_type': 'Position',
#   'forenduserdisplay': 'false',
#   'name': 'young receptionist',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Position',
#   'instances': [{'detection': '[ Mr. Jia’s wife and frequent star, plays Xiao Yu, ]a young receptionist[ at a sauna. It’s immediately clear that she’s]',
#     'prefix': ' Mr. Jia’s wife and frequent star, plays Xiao Yu, ',
#     'exact': 'a young receptionist',
#     'suffix': ' at a sauna. It’s immediately clear that she’s',
#     'offset': 11647,
#     'length': 20}],
#   'relevance': 0.2},
#  'http://d.opencalais.com/pershash-1/d0e22ef3-f558-37bb-9b8d-787d52ba9cf6': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'name': 'Yang-Yang',
#   'lastname': 'Yang-yang',
#   'nationality': 'N/A',
#   'persontype': 'N/A',
#   'confidencelevel': '0.961',
#   'commonname': 'Yang-Yang',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[ a great novel. Its point of view is shared among ]Yang-Yang[, his older sister, Ting-Ting, and their father,]',
#     'prefix': ' a great novel. Its point of view is shared among ',
#     'exact': 'Yang-Yang',
#     'suffix': ', his older sister, Ting-Ting, and their father,',
#     'offset': 17123,
#     'length': 9},
#    {'detection': '[Its point of view is shared among Yang-Yang, ]his[ older sister, Ting-Ting, and their father, N.J.,]',
#     'prefix': 'Its point of view is shared among Yang-Yang, ',
#     'exact': 'his',
#     'suffix': ' older sister, Ting-Ting, and their father, N.J.,',
#     'offset': 17134,
#     'length': 3}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.974',
#    'dblookup': '0.0',
#    'resolution': '0.0',
#    'aggregate': '0.961'}},
#  'http://d.opencalais.com/pershash-1/73b40e4b-54a3-31f9-874c-df75795c6577': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'confidencelevel': '0.969',
#   'lastname': 'Lazarescu',
#   'nationality': 'N/A',
#   'name': 'Dante Lazarescu',
#   'persontype': 'N/A',
#   'commonname': 'Dante Lazarescu',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[stage actress Luminita Gheorghiu, becomes ]Lazarescu’s[ advocate and ally, the one person able to]',
#     'prefix': 'stage actress Luminita Gheorghiu, becomes ',
#     'exact': 'Lazarescu’s',
#     'suffix': ' advocate and ally, the one person able to',
#     'offset': 16090,
#     'length': 11},
#    {'detection': '[by their own authority that they are blind to ]his[ suffering.\nAn ambulance driver, played by the]',
#     'prefix': 'by their own authority that they are blind to ',
#     'exact': 'his',
#     'suffix': ' suffering.\nAn ambulance driver, played by the',
#     'offset': 15983,
#     'length': 3},
#    {'detection': '[ Eastern European bureaucracy and the detritus of ]his[ own bad decisions. He is imperiled by the]',
#     'prefix': ' Eastern European bureaucracy and the detritus of ',
#     'exact': 'his',
#     'suffix': ' own bad decisions. He is imperiled by the',
#     'offset': 15796,
#     'length': 3},
#    {'detection': '[in his early 60s (though he looks older), ]he[ is complaining of stomach pains. A little more]',
#     'prefix': 'in his early 60s (though he looks older), ',
#     'exact': 'he',
#     'suffix': ' is complaining of stomach pains. A little more',
#     'offset': 14304,
#     'length': 2},
#    {'detection': '[ Dante Lazarescu, a retired Bucharest resident in ]his[ early 60s (though he looks older), he is]',
#     'prefix': ' Dante Lazarescu, a retired Bucharest resident in ',
#     'exact': 'his',
#     'suffix': ' early 60s (though he looks older), he is',
#     'offset': 14265,
#     'length': 3},
#    {'detection': '[ a half hours later – more or less in real time – ]he[ has left this world, unmourned and all but]',
#     'prefix': ' a half hours later – more or less in real time – ',
#     'exact': 'he',
#     'suffix': ' has left this world, unmourned and all but',
#     'offset': 14416,
#     'length': 2},
#    {'detection': '[Bucharest resident in his early 60s (though ]he[ looks older), he is complaining of stomach]',
#     'prefix': 'Bucharest resident in his early 60s (though ',
#     'exact': 'he',
#     'suffix': ' looks older), he is complaining of stomach',
#     'offset': 14287,
#     'length': 2},
#    {'detection': '[At the Cannes Film Festival, “ The Death of Mr. ]Lazarescu[ ” was a word-of-mouth sensation. “Did you see]',
#     'prefix': 'At the Cannes Film Festival, “ The Death of Mr. ',
#     'exact': 'Lazarescu',
#     'suffix': ' ” was a word-of-mouth sensation. “Did you see',
#     'offset': 14658,
#     'length': 9},
#    {'detection': '[which is no accident. Poor Mr. Lazarescu is ]his[ own kind of Everyman, caught not in the shiny]',
#     'prefix': 'which is no accident. Poor Mr. Lazarescu is ',
#     'exact': 'his',
#     'suffix': ' own kind of Everyman, caught not in the shiny',
#     'offset': 15630,
#     'length': 3},
#    {'detection': '[of Willy Loman, which is no accident. Poor Mr. ]Lazarescu[ is his own kind of Everyman, caught not in the]',
#     'prefix': 'of Willy Loman, which is no accident. Poor Mr. ',
#     'exact': 'Lazarescu',
#     'suffix': ' is his own kind of Everyman, caught not in the',
#     'offset': 15617,
#     'length': 9},
#    {'detection': '[ Scott The title is a spoiler. When we first meet ]Dante Lazarescu[, a retired Bucharest resident in his early 60s]',
#     'prefix': ' Scott The title is a spoiler. When we first meet ',
#     'exact': 'Dante Lazarescu',
#     'suffix': ', a retired Bucharest resident in his early 60s',
#     'offset': 14216,
#     'length': 15},
#    {'detection': '[and the detritus of his own bad decisions. ]He[ is imperiled by the arrogance and indifference]',
#     'prefix': 'and the detritus of his own bad decisions. ',
#     'exact': 'He',
#     'suffix': ' is imperiled by the arrogance and indifference',
#     'offset': 15819,
#     'length': 2}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.984',
#    'dblookup': '0.0',
#    'resolution': '0.0',
#    'aggregate': '0.969'}},
#  'http://d.opencalais.com/pershash-1/7db4ba4e-2476-3716-8a4f-cbc6ecfd03eb': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'firstname': 'Morgan',
#   'nationality': 'N/A',
#   'persontype': 'N/A',
#   'name': 'Morgan Freeman',
#   'lastname': 'Freeman',
#   'confidencelevel': '0.979',
#   'commonname': 'Morgan Freeman',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[ notes of feeling that nobody had noticed before.\n]Morgan Freeman[ and Hilary Swank each won Oscars for their]',
#     'prefix': ' notes of feeling that nobody had noticed before.\n',
#     'exact': 'Morgan Freeman',
#     'suffix': ' and Hilary Swank each won Oscars for their',
#     'offset': 10161,
#     'length': 14},
#    {'detection': '[each won Oscars for their performances. Mr. ]Freeman[ plays a former fighter nicknamed Scrap who acts]',
#     'prefix': 'each won Oscars for their performances. Mr. ',
#     'exact': 'Freeman',
#     'suffix': ' plays a former fighter nicknamed Scrap who acts',
#     'offset': 10237,
#     'length': 7}],
#   'relevance': 0.2,
#   'confidence': {'statisticalfeature': '0.97',
#    'dblookup': '0.95',
#    'resolution': '0.0',
#    'aggregate': '0.979'}},
#  'http://d.opencalais.com/comphash-1/22b46470-b64a-3af3-949a-b461fad44500': {'_typeGroup': 'entities',
#   '_type': 'Company',
#   'forenduserdisplay': 'false',
#   'name': 'Facebook',
#   'nationality': 'N/A',
#   'confidencelevel': '0.915',
#   'recognizedas': 'name',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Company',
#   'instances': [{'detection': '[to rank, with some help from cinema savants on ]Facebook[, the top 25 movies that are destined to be the]',
#     'prefix': 'to rank, with some help from cinema savants on ',
#     'exact': 'Facebook',
#     'suffix': ', the top 25 movies that are destined to be the',
#     'offset': 540,
#     'length': 8},
#    {'detection': '[seems, has a different favorite Pixar movie. On ]Facebook[, we asked our readers to choose theirs, and it]',
#     'prefix': 'seems, has a different favorite Pixar movie. On ',
#     'exact': 'Facebook',
#     'suffix': ', we asked our readers to choose theirs, and it',
#     'offset': 19249,
#     'length': 8},
#    {'detection': "[choose?\nAll !! Can't choose. Dina Dasom Anya on ]Facebook[\nMy Top 3 would have to be 1. Monsters Inc., 2.]",
#     'prefix': "choose?\nAll !! Can't choose. Dina Dasom Anya on ",
#     'exact': 'Facebook',
#     'suffix': '\nMy Top 3 would have to be 1. Monsters Inc., 2.',
#     'offset': 21091,
#     'length': 8},
#    {'detection': '[you know, ninjas cutting onions. Leia Becker on ]Facebook[\nMost people can only see the terrible crisis]',
#     'prefix': 'you know, ninjas cutting onions. Leia Becker on ',
#     'exact': 'Facebook',
#     'suffix': '\nMost people can only see the terrible crisis',
#     'offset': 21276,
#     'length': 8},
#    {'detection': "[to create a movie about it. Andres Ollarvez on ]Facebook[\nHands down, Up. Russell was my Chinese father's]",
#     'prefix': 'to create a movie about it. Andres Ollarvez on ',
#     'exact': 'Facebook',
#     'suffix': "\nHands down, Up. Russell was my Chinese father's",
#     'offset': 21527,
#     'length': 8},
#    {'detection': '[win for me and my family. Tracy Lee Murphy on ]Facebook[\nThe best film of the 21 Century is The]',
#     'prefix': 'win for me and my family. Tracy Lee Murphy on ',
#     'exact': 'Facebook',
#     'suffix': '\nThe best film of the 21 Century is The',
#     'offset': 21744,
#     'length': 8},
#    {'detection': "[21 Century is The Incredibles. Muuka Muyumba on ]Facebook[\nThe Incredibles is my kids' favorite, and the]",
#     'prefix': '21 Century is The Incredibles. Muuka Muyumba on ',
#     'exact': 'Facebook',
#     'suffix': "\nThe Incredibles is my kids' favorite, and the",
#     'offset': 21822,
#     'length': 8},
#    {'detection': '[(especially) “Take Traction!” Craig Pittman on ]Facebook[\nWall-E - I never knew a film could capture and]',
#     'prefix': '(especially) “Take Traction!” Craig Pittman on ',
#     'exact': 'Facebook',
#     'suffix': '\nWall-E - I never knew a film could capture and',
#     'offset': 22021,
#     'length': 8},
#    {'detection': '[such little language. Rachel Morgan Spencer on ]Facebook[\nMonsters, Inc. The message of laughter over fear]',
#     'prefix': 'such little language. Rachel Morgan Spencer on ',
#     'exact': 'Facebook',
#     'suffix': '\nMonsters, Inc. The message of laughter over fear',
#     'offset': 22178,
#     'length': 8},
#    {'detection': "[have Sully in my life. Barb Beaser-Konschak on ]Facebook[\nRatatouille, just because it's so cleverly]",
#     'prefix': 'have Sully in my life. Barb Beaser-Konschak on ',
#     'exact': 'Facebook',
#     'suffix': "\nRatatouille, just because it's so cleverly",
#     'offset': 22346,
#     'length': 8},
#    {'detection': '[in the kitchen, right? Margarete Weathers on ]Facebook[\nToy Story 3 - felt destroyed by the sad but]',
#     'prefix': 'in the kitchen, right? Margarete Weathers on ',
#     'exact': 'Facebook',
#     'suffix': '\nToy Story 3 - felt destroyed by the sad but',
#     'offset': 22483,
#     'length': 8},
#    {'detection': '[the sad but appropriate ending! Michele Mai on ]Facebook[\nI’m in between “Toy Story 3” and “Inside Out”.]',
#     'prefix': 'the sad but appropriate ending! Michele Mai on ',
#     'exact': 'Facebook',
#     'suffix': '\nI’m in between “Toy Story 3” and “Inside Out”.',
#     'offset': 22571,
#     'length': 8},
#    {'detection': '[Out”. Can I be allowed a tie? Kyle Hambor on ]Facebook[\nWatching Inside Out with my daughters, both]',
#     'prefix': 'Out”. Can I be allowed a tie? Kyle Hambor on ',
#     'exact': 'Facebook',
#     'suffix': '\nWatching Inside Out with my daughters, both',
#     'offset': 22666,
#     'length': 8},
#    {'detection': '[down, my wife and I were a mess. Tim Riley on ]Facebook[\n8\nBoyhood\nDirected by Richard Linklater,]',
#     'prefix': 'down, my wife and I were a mess. Tim Riley on ',
#     'exact': 'Facebook',
#     'suffix': '\n8\nBoyhood\nDirected by Richard Linklater,',
#     'offset': 22880,
#     'length': 8}],
#   'relevance': 0,
#   'resolutions': [{'name': 'META PLATFORMS, INC.',
#     'permid': '4297297477',
#     'primaryric': 'META.OQ',
#     'ispublic': 'true',
#     'commonname': 'Meta Platforms',
#     'score': 0.29620355,
#     'id': 'https://permid.org/1-4297297477',
#     'ticker': 'META'}],
#   'confidence': {'statisticalfeature': '0.969',
#    'dblookup': '0.0',
#    'resolution': '0.29620355',
#    'aggregate': '0.915'}},
#  'http://d.opencalais.com/pershash-1/0914098e-78f9-3612-bf1c-2426468bb03d': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'persontype': 'N/A',
#   'name': 'Donald J. Trump',
#   'confidencelevel': '0.992',
#   'nationality': 'N/A',
#   'commonname': 'Donald Trump',
#   'confidence': {'statisticalfeature': '0.988',
#    'dblookup': '0.95',
#    'resolution': '0.0',
#    'aggregate': '0.992'},
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[craft, producing some of the strongest work of ]his[ career and also some of the strangest. A ghost]',
#     'prefix': 'craft, producing some of the strongest work of ',
#     'exact': 'his',
#     'suffix': ' career and also some of the strangest. A ghost',
#     'offset': 9576,
#     'length': 3},
#    {'detection': '[ in 2000, he has continued to practice and refine ]his[ craft, producing some of the strongest work of]',
#     'prefix': ' in 2000, he has continued to practice and refine ',
#     'exact': 'his',
#     'suffix': ' craft, producing some of the strongest work of',
#     'offset': 9525,
#     'length': 3},
#    {'detection': '[Convention in 2012 and expressed admiration for ]Donald J. Trump[ during the 2016 campaign. But that’s just his]',
#     'prefix': 'Convention in 2012 and expressed admiration for ',
#     'exact': 'Donald J. Trump',
#     'suffix': ' during the 2016 campaign. But that’s just his',
#     'offset': 9350,
#     'length': 15},
#    {'detection': '[Trump during the 2016 campaign. But that’s just ]his[ way of passing the time and letting off steam.]',
#     'prefix': 'Trump during the 2016 campaign. But that’s just ',
#     'exact': 'his',
#     'suffix': ' way of passing the time and letting off steam.',
#     'offset': 9408,
#     'length': 3},
#    {'detection': '[ and letting off steam. Since turning 70 in 2000, ]he[ has continued to practice and refine his craft,]',
#     'prefix': ' and letting off steam. Since turning 70 in 2000, ',
#     'exact': 'he',
#     'suffix': ' has continued to practice and refine his craft,',
#     'offset': 9485,
#     'length': 2}],
#   'relevance': 0.2},
#  'http://d.opencalais.com/genericHasher-1/155a1000-242c-3590-b78e-e17d27ec404b': {'_typeGroup': 'entities',
#   '_type': 'City',
#   'forenduserdisplay': 'true',
#   'name': 'Bucharest',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/City',
#   'instances': [{'detection': '[When we first meet Dante Lazarescu, a retired ]Bucharest[ resident in his early 60s (though he looks]',
#     'prefix': 'When we first meet Dante Lazarescu, a retired ',
#     'exact': 'Bucharest',
#     'suffix': ' resident in his early 60s (though he looks',
#     'offset': 14243,
#     'length': 9},
#    {'detection': '[the streets, tenements and emergency rooms of ]Bucharest[. The title might remind you of Willy Loman,]',
#     'prefix': 'the streets, tenements and emergency rooms of ',
#     'exact': 'Bucharest',
#     'suffix': '. The title might remind you of Willy Loman,',
#     'offset': 15532,
#     'length': 9}],
#   'relevance': 0.2,
#   'resolutions': [{'name': 'Bucharest,Romania',
#     'shortname': 'Bucharest',
#     'latitude': '44.4167',
#     'longitude': '26.1',
#     'containedbycountry': 'Romania',
#     'rcscode': 'G:27W'}]},
#  'http://d.opencalais.com/pershash-1/0ce290fb-e354-3f36-b28e-86f591291f30': {'_typeGroup': 'entities',
#   '_type': 'Person',
#   'forenduserdisplay': 'true',
#   'nationality': 'N/A',
#   'name': 'Oscar',
#   'lastname': 'Oscar',
#   'confidencelevel': '0.987',
#   'persontype': 'N/A',
#   'commonname': 'Oscar',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/e/Person',
#   'permid': 'https://permid.org/1-404011',
#   'instances': [{'detection': '[Baby” (which won him his second best picture ]Oscar)[, he has occasionally wandered into the public]',
#     'prefix': 'Baby” (which won him his second best picture ',
#     'exact': 'Oscar)',
#     'suffix': ', he has occasionally wandered into the public',
#     'offset': 9109,
#     'length': 6},
#    {'detection': '[(which won him his second best picture Oscar), ]he[ has occasionally wandered into the public eye]',
#     'prefix': '(which won him his second best picture Oscar), ',
#     'exact': 'he',
#     'suffix': ' has occasionally wandered into the public eye',
#     'offset': 9117,
#     'length': 2},
#    {'detection': '[the public eye for reasons unrelated to movies. ]He[ appeared in a memorable Chrysler commercial ,]',
#     'prefix': 'the public eye for reasons unrelated to movies. ',
#     'exact': 'He',
# ...
#   'relevance': 0.2},
#  'http://d.opencalais.com/genericHasher-1/ba8c20e5-fc90-366f-9567-ca5911952da3': {'_typeGroup': 'relations',
#   '_type': 'Quotation',
#   'forenduserdisplay': 'true',
#   'quotation': '– and once again Xiao Yu declines',
#   'quotationtype': 'Paraphrase',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/Quotation',
#   'speaker': 'http://d.opencalais.com/pershash-1/e8f20e58-67a5-31b5-94e2-2318c344ac3a',
#   'instances': [{'detection': '[seen the second guy before; he’s a local thug. ]He too demands a massage – “we can afford you,” he says – and once again Xiao Yu declines.[ “I’m not a prostitute,” she says. “Go home to]',
#     'prefix': 'seen the second guy before; he’s a local thug. ',
#     'exact': 'He too demands a massage – “we can afford you,” he says – and once again Xiao Yu declines.',
#     'suffix': ' “I’m not a prostitute,” she says. “Go home to',
#     'offset': 12734,
#     'length': 90}]},
#  'http://d.opencalais.com/genericHasher-1/7f76a949-2412-388e-8ca7-9e2a2109f16a': {'_typeGroup': 'relations',
#   '_type': 'Quotation',
#   'forenduserdisplay': 'true',
#   'quotation': 'pushing her down hard',
#   'quotationtype': 'Paraphrase',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/Quotation',
#   'speaker': 'http://d.opencalais.com/pershash-1/e8f20e58-67a5-31b5-94e2-2318c344ac3a',
#   'instances': [{'detection': '[but the second guy bursts in. “I’m having you!]” he exclaims, pushing her down hard.[ She stands; he pushes her down. She stands]',
#     'prefix': 'but the second guy bursts in. “I’m having you!',
#     'exact': '” he exclaims, pushing her down hard.',
#     'suffix': ' She stands; he pushes her down. She stands',
#     'offset': 12950,
#     'length': 37}]},
#  'http://d.opencalais.com/genericHasher-1/17604f6a-38bf-3c44-90d1-468dbb7f1740': {'_typeGroup': 'relations',
#   '_type': 'PersonCareer',
#   'forenduserdisplay': 'true',
#   'position': 'director',
#   'careertype': 'professional',
#   'status': 'current',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/PersonCareer',
#   'person': 'http://d.opencalais.com/pershash-1/9912c82d-5b99-3093-a4a6-d575110717f3',
#   'company': 'http://d.opencalais.com/comphash-1/2bab3fcb-8f2d-3c01-b6ba-f1ea4a68a5a6',
#   'instances': [{'detection': '[Touch of Sin ” is an astonishing movie from the ]Chinese director Jia Zhangke[. Divided into four chapters, it was inspired by]',
#     'prefix': 'Touch of Sin ” is an astonishing movie from the ',
#     'exact': 'Chinese director Jia Zhangke',
#     'suffix': '. Divided into four chapters, it was inspired by',
#     'offset': 11319,
#     'length': 28}]},
#  'http://d.opencalais.com/genericHasher-1/56a91f6d-8d95-3478-b4d8-ac70429e9648': {'_typeGroup': 'relations',
#   '_type': 'ArmedAttack',
#   'forenduserdisplay': 'true',
#   'partyinvolved2': 'the drilling rig midway',
#   'attacktype': 'explosion',
#   'status': 'confirmed',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/ArmedAttack',
#   'instances': [{'detection': '[the many bravura set pieces that follow, like ]the explosion of the drilling rig midway[ through. The grandeur of Mr. Anderson’s vision]',
#     'prefix': 'the many bravura set pieces that follow, like ',
#     'exact': 'the explosion of the drilling rig midway',
#     'suffix': ' through. The grandeur of Mr. Anderson’s vision',
#     'offset': 2920,
#     'length': 40}]},
#  'http://d.opencalais.com/genericHasher-1/0846b8f1-1c58-3379-ba15-faf03f9271a5': {'_typeGroup': 'relations',
#   '_type': 'FamilyRelation',
#   'forenduserdisplay': 'true',
#   'familyrelationtype': 'sister',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/FamilyRelation',
#   'person': 'http://d.opencalais.com/pershash-1/0fa73091-3a38-3e15-a83a-5bf7149df581',
#   'person_relative': 'http://d.opencalais.com/pershash-1/f8a08ae9-8ba6-3af8-8b73-2d7c92a385f5',
#   'instances': [{'detection': '[Its point of view is shared among Yang-Yang, ]his older sister, Ting-Ting[, and their father, N.J., a video-game designer]',
#     'prefix': 'Its point of view is shared among Yang-Yang, ',
#     'exact': 'his older sister, Ting-Ting',
#     'suffix': ', and their father, N.J., a video-game designer',
#     'offset': 17134,
#     'length': 27}]},
#  'http://d.opencalais.com/genericHasher-1/b05db79f-505f-3c4f-a098-8e6ec5cf108e': {'_typeGroup': 'relations',
#   '_type': 'PersonCareer',
#   'forenduserdisplay': 'true',
#   'position': 'preacher',
#   'careertype': 'professional',
#   'status': 'current',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/PersonCareer',
#   'person': 'http://d.opencalais.com/pershash-1/7dc3a4c4-da9a-3441-9a21-756a9ffdad92',
#   'company': 'http://d.opencalais.com/comphash-1/22b46470-b64a-3af3-949a-b461fad44500',
#   'instances': [{'detection': '[ land. He also establishes an uneasy rivalry with ]a preacher, Eli Sunday[, and the two men, each selling his own brand of]',
#     'prefix': ' land. He also establishes an uneasy rivalry with ',
#     'exact': 'a preacher, Eli Sunday',
#     'suffix': ', and the two men, each selling his own brand of',
#     'offset': 1212,
#     'length': 22}]},
#  'http://d.opencalais.com/genericHasher-1/2f5667d5-888a-3cc1-bddf-e283e0a6ccdb': {'_typeGroup': 'relations',
#   '_type': 'Quotation',
#   'forenduserdisplay': 'true',
#   'quotation': 'she’s not a masseuse and shuts the door.',
#   'quotationtype': 'Paraphrase',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/Quotation',
#   'speaker': 'http://d.opencalais.com/pershash-1/e6a88f45-9fa6-3069-973e-0a3c905b0908',
#   'instances': [{'detection': '[ the door, demanding that she give him a massage. ]She explains that she’s not a masseuse and shuts the door.[ He returns – she shoos him off – and then he]',
#     'prefix': ' the door, demanding that she give him a massage. ',
#     'exact': 'She explains that she’s not a masseuse and shuts the door.',
#     'suffix': ' He returns – she shoos him off – and then he',
#     'offset': 12550,
#     'length': 58}]},
#  'http://d.opencalais.com/genericHasher-1/c521a2da-6986-3247-b1a9-e373bb456995': {'_typeGroup': 'relations',
#   '_type': 'FamilyRelation',
#   'forenduserdisplay': 'true',
#   'familyrelationtype': 'wife',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/FamilyRelation',
#   'person': 'http://d.opencalais.com/pershash-1/9912c82d-5b99-3093-a4a6-d575110717f3',
#   'person_relative': 'http://d.opencalais.com/pershash-1/2d8ff5d5-def9-340f-bc80-6ff8706674b6',
#   'instances': [{'detection': '[– to “paint the face” of contemporary China.\n]Zhao Tao, Mr. Jia’s wife and frequent[ star, plays Xiao Yu, a young receptionist at a]',
#     'prefix': '– to “paint the face” of contemporary China.\n',
#     'exact': 'Zhao Tao, Mr. Jia’s wife and frequent',
#     'suffix': ' star, plays Xiao Yu, a young receptionist at a',
#     'offset': 11588,
#     'length': 37}]},
#  'http://d.opencalais.com/genericHasher-1/e12b9f42-f496-3771-b807-6e4573b388ba': {'_typeGroup': 'relations',
#   '_type': 'EmploymentRelation',
#   'forenduserdisplay': 'true',
#   'position': 'advocate',
#   'status': 'current',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/EmploymentRelation',
#   'person_employer': 'http://d.opencalais.com/pershash-1/73b40e4b-54a3-31f9-874c-df75795c6577',
#   'person_employee': 'http://d.opencalais.com/pershash-1/14232413-1955-3863-a026-cf00f1b6ca19',
#   'instances': [{'detection': '[played by the great Romanian stage actress ]Luminita Gheorghiu, becomes Lazarescu’s advocate[ and ally, the one person able to insist,]',
#     'prefix': 'played by the great Romanian stage actress ',
#     'exact': 'Luminita Gheorghiu, becomes Lazarescu’s advocate',
#     'suffix': ' and ally, the one person able to insist,',
#     'offset': 16062,
#     'length': 48}]},
#  'http://d.opencalais.com/genericHasher-1/904bd6bc-6434-3a13-a8e8-0eef83cae82e': {'_typeGroup': 'relations',
#   '_type': 'PersonRelation',
#   'forenduserdisplay': 'true',
#   'personrelationtype': 'romantic',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/PersonRelation',
#   'person': ['http://d.opencalais.com/pershash-1/9912c82d-5b99-3093-a4a6-d575110717f3',
#    'http://d.opencalais.com/pershash-1/2d8ff5d5-def9-340f-bc80-6ff8706674b6'],
#   'instances': [{'detection': '[– to “paint the face” of contemporary China.\n]Zhao Tao, Mr. Jia’s wife and frequent[ star, plays Xiao Yu, a young receptionist at a]',
#     'prefix': '– to “paint the face” of contemporary China.\n',
#     'exact': 'Zhao Tao, Mr. Jia’s wife and frequent',
#     'suffix': ' star, plays Xiao Yu, a young receptionist at a',
#     'offset': 11588,
#     'length': 37}]},
#  'http://d.opencalais.com/genericHasher-1/3c7ad3f5-20d8-33ee-b378-f9829462504b': {'_typeGroup': 'relations',
#   '_type': 'PersonCommunication',
#   'forenduserdisplay': 'true',
#   'status': 'announced',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/PersonCommunication',
#   'person': ['http://d.opencalais.com/pershash-1/9742aa73-f20c-3926-87ef-30c328e55926',
#    'http://d.opencalais.com/pershash-1/0fa73091-3a38-3e15-a83a-5bf7149df581'],
#   'instances': [{'detection': '[in his own right, to share his thoughts. ]He spoke by phone with A.O. Scott[. Here are edited excerpts from his]',
#     'prefix': 'in his own right, to share his thoughts. ',
#     'exact': 'He spoke by phone with A.O. Scott',
#     'suffix': '. Here are edited excerpts from his',
#     'offset': 5442,
#     'length': 33}]},
#  'http://d.opencalais.com/genericHasher-1/2f0f93ce-9af2-3f0e-a505-bfb2ba66cb92': {'_typeGroup': 'relations',
#   '_type': 'PersonCareer',
#   'forenduserdisplay': 'true',
#   'position': 'King',
#   'careertype': 'political',
#   'status': 'current',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/PersonCareer',
#   'person': 'http://d.opencalais.com/pershash-1/25404e3d-afc1-3e05-991f-a865a3839345',
#   'instances': [{'detection': '[China, but here he also borrows from ]King Hu[’s “A Touch of Zen,” a 1971 martial arts classic.]',
#     'prefix': 'China, but here he also borrows from ',
#     'exact': 'King Hu',
#     'suffix': '’s “A Touch of Zen,” a 1971 martial arts classic.',
#     'offset': 13551,
#     'length': 7}]},
#  'http://d.opencalais.com/genericHasher-1/44a7ca09-01b3-3dc8-8e46-e08d0dce3f5a': {'_typeGroup': 'relations',
#   '_type': 'Quotation',
#   'forenduserdisplay': 'true',
#   'quotation': 'with an empty chair at the Republican National Convention in 2012 and expressed admiration for Donald J. Trump during the 2016 campaign',
#   'quotationtype': 'Paraphrase',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/Quotation',
#   'speaker': 'http://d.opencalais.com/comphash-1/2bab3fcb-8f2d-3c01-b6ba-f1ea4a68a5a6',
#   'instances': [{'detection': '[the public eye for reasons unrelated to movies. ]He appeared in a memorable Chrysler commercial , argued with an empty chair at the Republican National Convention in 2012 and expressed admiration for Donald J. Trump during the 2016 campaign.[ But that’s just his way of passing the time and]',
#     'prefix': 'the public eye for reasons unrelated to movies. ',
#     'exact': 'He appeared in a memorable Chrysler commercial , argued with an empty chair at the Republican National Convention in 2012 and expressed admiration for Donald J. Trump during the 2016 campaign.',
#     'suffix': ' But that’s just his way of passing the time and',
#     'offset': 9199,
#     'length': 192}]},
#  'http://d.opencalais.com/genericHasher-1/b2a4141f-f764-39ae-8edb-50835d5c4284': {'_typeGroup': 'relations',
#   '_type': 'PersonCareer',
#   'forenduserdisplay': 'true',
#   'position': 'young receptionist',
#   'careertype': 'professional',
#   'status': 'current',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/PersonCareer',
#   'person': 'http://d.opencalais.com/pershash-1/e8f20e58-67a5-31b5-94e2-2318c344ac3a',
#   'instances': [{'detection': '[Tao, Mr. Jia’s wife and frequent star, plays ]Xiao Yu, a young receptionist[ at a sauna. It’s immediately clear that she’s]',
#     'prefix': 'Tao, Mr. Jia’s wife and frequent star, plays ',
#     'exact': 'Xiao Yu, a young receptionist',
#     'suffix': ' at a sauna. It’s immediately clear that she’s',
#     'offset': 11638,
#     'length': 29}]},
#  'http://d.opencalais.com/genericHasher-1/063eaaf5-45ff-3245-b29e-1ef4bfd7911f': {'_typeGroup': 'relations',
#   '_type': 'PersonLocation',
#   'forenduserdisplay': 'false',
#   'persongroup': 'a kid',
#   'locationstring': 'Mexico',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/PersonLocation',
#   'instances': [{'detection': '[del Toro I discovered Miyazaki when I ]was a kid in Mexico[. I remember seeing a sequence Miyazaki and [his]',
#     'prefix': 'del Toro I discovered Miyazaki when I ',
#     'exact': 'was a kid in Mexico',
#     'suffix': '. I remember seeing a sequence Miyazaki and [his',
#     'offset': 5716,
#     'length': 19}]},
#  'http://d.opencalais.com/genericHasher-1/5c29f6c1-ffb4-3c4d-a5ca-545042a6fde6': {'_typeGroup': 'relations',
#   '_type': 'PersonCareer',
#   'forenduserdisplay': 'true',
#   'position': 'composer',
#   'careertype': 'professional',
#   'status': 'current',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/PersonCareer',
#   'person': 'http://d.opencalais.com/pershash-1/12f6d8a9-c41f-32b4-af7b-0c6920aee6e4',
#   'company': 'http://d.opencalais.com/comphash-1/22b46470-b64a-3af3-949a-b461fad44500',
#   'instances': [{'detection': '[(notably the cinematographer Robert Elswit and ]the composer Jonny Greenwood[) in the service of his ideas.\nI never tire of]',
#     'prefix': '(notably the cinematographer Robert Elswit and ',
#     'exact': 'the composer Jonny Greenwood',
#     'suffix': ') in the service of his ideas.\nI never tire of',
#     'offset': 3425,
#     'length': 28}]},
#  'http://d.opencalais.com/genericHasher-1/0c019d3c-b539-3c4f-b6ee-edc5c535764c': {'_typeGroup': 'relations',
#   '_type': 'PersonRelation',
#   'forenduserdisplay': 'true',
#   'personrelationtype': 'Buisness',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/PersonRelation',
#   'person': ['http://d.opencalais.com/pershash-1/9742aa73-f20c-3926-87ef-30c328e55926',
#    'http://d.opencalais.com/pershash-1/04495cef-b639-3cf9-aabd-d94431ca2894'],
#   'instances': [{'detection': '[I remember seeing a sequence Miyazaki and []his colleague Otsuka Yasuo[] did on a movie called “Puss in Boots” of an]',
#     'prefix': 'I remember seeing a sequence Miyazaki and [',
#     'exact': 'his colleague Otsuka Yasuo',
#     'suffix': '] did on a movie called “Puss in Boots” of an',
#     'offset': 5780,
#     'length': 26}]},
#  'http://d.opencalais.com/genericHasher-1/4e8d3897-d943-370d-8d64-90bb2fb57ad2': {'_typeGroup': 'relations',
#   '_type': 'PersonCareer',
#   'forenduserdisplay': 'true',
#   'position': 'stage actress',
#   'careertype': 'professional',
#   'status': 'current',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/PersonCareer',
#   'person': 'http://d.opencalais.com/pershash-1/14232413-1955-3863-a026-cf00f1b6ca19',
#   'company': 'http://d.opencalais.com/comphash-1/2bab3fcb-8f2d-3c01-b6ba-f1ea4a68a5a6',
#   'instances': [{'detection': '[ambulance driver, played by the great ]Romanian stage actress Luminita Gheorghiu[, becomes Lazarescu’s advocate and ally, the one]',
#     'prefix': 'ambulance driver, played by the great ',
#     'exact': 'Romanian stage actress Luminita Gheorghiu',
#     'suffix': ', becomes Lazarescu’s advocate and ally, the one',
#     'offset': 16039,
#     'length': 41}]},
#  'http://d.opencalais.com/genericHasher-1/6f5b5650-ff9a-3309-a747-5ae1ad273e56': {'_typeGroup': 'relations',
#   '_type': 'PersonRelation',
#   'forenduserdisplay': 'true',
#   'personrelationtype': 'romantic',
#   '_typeReference': 'http://s.opencalais.com/1/type/em/r/PersonRelation',
#   'person': ['http://d.opencalais.com/pershash-1/9b32cf5d-0540-3de7-a31e-af37865ef892',
#    'http://d.opencalais.com/pershash-1/e34b402f-64d8-3540-94b9-e93d91260954'],
#   'instances': [{'detection': '[least a half-dozen films: the wordless story of ]Carl and Ellie’s marriage[ in “Up”; the first meeting of Wall-E and Eve;]',
#     'prefix': 'least a half-dozen films: the wordless story of ',
#     'exact': 'Carl and Ellie’s marriage',
#     'suffix': ' in “Up”; the first meeting of Wall-E and Eve;',
#     'offset': 19879,
#     'length': 25}]}}

# %% [markdown]
# ### 2.2 Create a list of all the recognized entities attached to article title

# %%
#Get Entities
entity_dict = {}

print('====Entities====')
print('Article_No, Type, Name, Article Title')
art_no = 0
dict_key = 0
for TRITJsonResponse in all_JsonResponses:
    art_no += 1
    for key in TRITJsonResponse:
        dict_key += 1
        if ('_typeGroup' in TRITJsonResponse[key]):
            if TRITJsonResponse[key]['_typeGroup'] == 'entities':
                entities = str(art_no) + ", " + TRITJsonResponse[key]['_type'] + ", " + TRITJsonResponse[key]['name'] + ", " + all_headlines[art_no]
                entity_dict[dict_key] = entities
# Out:
# ====Entities====
# Article_No, Type, Name, Article Title

# %%
entity_dict[14]
# Out:
# '1, Person, Ellen Burstyn, The 25 Greatest Actors of the 21st Century (So Far)'

# %%
#Get Entities
entity_list2 = []

print('====Entities====')
print('Article_No, Type, Name, Article Title')
art_no = 0
for TRITJsonResponse in all_JsonResponses:
    art_no += 1
    for key in TRITJsonResponse:
        if ('_typeGroup' in TRITJsonResponse[key]):
            if TRITJsonResponse[key]['_typeGroup'] == 'entities':
                entities = str(art_no) + ", " + TRITJsonResponse[key]['_type'] + ", " + TRITJsonResponse[key]['name'] + ", " + all_headlines[art_no]
                entity_list2.append(entities)
# Out:
# ====Entities====
# Article_No, Type, Name, Article Title

# %% [markdown]
# ## 2.3 Search articles by movie name, company, or person

# %% [markdown]
# *Method 1*: Print articles that includes the search value (multiple definitions)

# %%
def search_by_value(dictionary, search_value):
    keys_with_search_value = []
    for key, value in dictionary.items():
        if search_value in value:
            keys_with_search_value.append(key)
    return keys_with_search_value

def list_of_output(dictionary, keys_with_search_value):
    output_list = []
    for key in keys_with_search_value:
        output_list.append(f"Key: {key}, Value: {dictionary[key]}")    
    return output_list

def print_output(output_list):
    for values in output_list:
        print(values)

# %%
value = 'warner'#input search value

keys_with_search_value = search_by_value(entity_dict, value)
output = list_of_output(entity_dict, keys_with_search_value)
print_output(output)
# Out:
# Key: 92, Value: 1, Company, warner bros, The 25 Greatest Actors of the 21st Century (So Far)
# Key: 349, Value: 4, Company, warner bros, ‘Shaun the Sheep Movie’: Designing the Characters
# Key: 736, Value: 29, Company, warner bros, Hollywood as Biographer
# Key: 886, Value: 32, Company, warner bros, The 25 Greatest Actors of the 21st Century (So Far)
# Key: 948, Value: 34, Company, warner bros, Film Series Listings
# Key: 1186, Value: 36, Company, warner bros, The 25 Best Films of the 21st Century So Far.
# Key: 1620, Value: 42, Company, warner bros, 10 Sundance Movies With Heat
# Key: 2867, Value: 111, Company, warner bros, 2018 Academy Awards
# Key: 5067, Value: 178, Company, warner bros, The 25 Best Films of the 21st Century So Far.
# Key: 6791, Value: 233, Company, warner bros, 2018 Golden Globe Awards
# Key: 7097, Value: 237, Company, warner bros, Marlon Brando, Oscar-Winning Actor, Is Dead at 80
# Key: 8557, Value: 286, Company, warner bros, Golden Globes: The Projectionist’s Takeaways
# Key: 8735, Value: 289, Company, warner bros, What the Movies Taught Me About Being a Woman
# Key: 8900, Value: 290, Company, warner bros, 2018 Academy Awards
# Key: 10569, Value: 337, Company, warner bros, How Will Movies Survive the Next 10 Years?
# Key: 10739, Value: 338, Company, warner bros, 28 Days, 28 Films for Black History Month
# Key: 11324, Value: 344, Company, warner bros, New Books Look at the ‘Peanuts’ Gang
# Key: 11510, Value: 348, Company, warner bros, ‘Shaun the Sheep Movie’: Designing the Characters
# Key: 13419, Value: 488, Company, warner bros, Everything You Need to Know Before ‘Avengers: Endgame,’ in Two Minutes
# Key: 13621, Value: 490, Company, warner bros, You Know These 20 Movies. Now Meet the Women Behind Them
# Key: 13861, Value: 491, Company, warner bros, 28 Days, 28 Films for Black History Month
# Key: 14816, Value: 501, Company, warner bros, David Bowie in the Movies
# Key: 16536, Value: 596, Company, warner bros, How Will Movies Survive the Next 10 Years?
# Key: 16706, Value: 597, Company, warner bros, The 25 Best Films of the 21st Century So Far.
# Key: 17551, Value: 628, Company, warner bros, What the Movies Taught Me About Being a Woman
# Key: 17731, Value: 629, Company, warner bros, The 25 Best Films of the 21st Century So Far.
# Key: 18217, Value: 645, Company, warner bros, The 25 Greatest Actors of the 21st Century (So Far)
# Key: 18411, Value: 648, Company, warner bros, 2020 Oscar Nominations: Full Ballot
# Key: 18590, Value: 650, Company, warner bros, And the 2019 Oscar Nominees Should Be …
# Key: 18658, Value: 651, Company, warner bros, What the Movies Taught Me About Being a Woman
# Key: 18788, Value: 652, Company, warner bros, 28 Days, 28 Films for Black History Month
# Key: 20196, Value: 702, Company, warner bros, The 25 Best Films of the 21st Century So Far.
# Key: 20834, Value: 708, Company, warner bros, Guillermo del Toro’s House of Horrors
# Key: 21043, Value: 710, Company, warner bros, Faces to Watch

# %% [markdown]
# *Method 2*: Print articles that includes the search value (one definition):

# %%
def print_output2 (dictionary, search_value):
    keys_with_search_value = []
    for key, value in dictionary.items():
        if search_value in value:
            keys_with_search_value.append(key)

    output_list = []
    for key in keys_with_search_value:
        output_list.append(f"Key: {key}, Value: {dictionary[key]}")    

    for values in output_list:
        print(values)

# %%
value = 'Tan'

print_output2(entity_dict, value)
# Out:
# Key: 540, Value: 22, Movie, Black and Tan, From the BBC, a Watery World
# Key: 2099, Value: 84, Movie, Black and Tan, The 25 Best Films of the 21st Century So Far.
# Key: 2943, Value: 113, Movie, Black and Tan, 2018 Golden Globe Awards
# Key: 5368, Value: 181, Person, Richard Tanne, Aging Stars Don’t Fade Away, They Make More Movies
# Key: 6158, Value: 221, Movie, Black and Tan, The 25 Best Films of the 21st Century So Far.
# Key: 6506, Value: 227, Person, Richard Tanne, A Flurry of Horrors, Real and Imagined
# Key: 6954, Value: 236, Person, Richard Tanne, The Holiday Movie Season in Trailers
# Key: 8181, Value: 279, Movie, Black and Tan, The 25 Best Films of the 21st Century So Far.
# Key: 8961, Value: 292, Movie, Black and Tan, The 25 Best Films of the 21st Century So Far.
# Key: 10794, Value: 339, Movie, Black and Tan, The 25 Best Films of the 21st Century So Far.
# Key: 13940, Value: 492, Movie, Black and Tan, The 25 Best Films of the 21st Century So Far.
# Key: 14408, Value: 496, Person, Richard Tanne, Aging Stars Don’t Fade Away, They Make More Movies
# Key: 17133, Value: 601, Person, Richard Tanne, ‘Minions’ and Its Influences: A Goggle-Eyed View
# Key: 18828, Value: 653, Movie, Black and Tan, The 25 Best Films of the 21st Century So Far.
# Key: 20448, Value: 704, Person, Richard Tanne, 8 Gold-Worthy Olympics Movies
# Key: 20611, Value: 706, Person, Richard Tanne, A ‘Star Wars’ Refresher
