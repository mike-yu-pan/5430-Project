# %%
import pandas as pd
import gzip

with gzip.open('C:/Users/123\Downloads/title.basics.tsv.gz', 'rt', encoding='utf-8') as f:
    df = pd.read_csv(f, delimiter='\t')
# Out:
# C:\Users\123\AppData\Local\Temp\ipykernel_28996\2636356860.py:5: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f, delimiter='\t')

# %%
df[50:60]
# Out:
#        tconst titleType                                       primaryTitle
# 50  tt0000052     short                                   Carga de rurales  \
# 51  tt0000053     short  A Chegada do Comboio Inaugural à Estação Centr...
# 52  tt0000054     short                                   A Merry-Go-Round
# 53  tt0000055     short                                     Le chiffonnier
# 54  tt0000056     short             Uma Corrida de Touros no Campo Pequeno
# 55  tt0000057     short                Cortège de tzar allant à Versailles
# 56  tt0000058     short                Cortège de tzar au Bois de Boulogne
# 57  tt0000059     short                     Coronation of a Village Maiden
# 58  tt0000060     short                                    Dancing Darkies
# 59  tt0000061     short                                      Dancing Girls
#
#                                         originalTitle isAdult startYear
# ...

# %%
df[df["tconst"] == "tt0105112"]
# Out:
#            tconst titleType   primaryTitle  originalTitle isAdult startYear
# 102763  tt0105112     movie  Patriot Games  Patriot Games       0      1992  \
#
#        endYear runtimeMinutes           genres
# 102763      \N            117  Action,Thriller
